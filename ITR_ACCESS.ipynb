# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %%
itr = pd.read_csv("Inventory.csv")  
hks = pd.read_csv("Hardware.KitchenSink.csv")

# %%
itr
# Out:
#       AutoID  Student_Number First_Name   Last_Name       ITR      Serial  \
# 0       6544             NaN        NaN         NaN   35019.0  5CD9092S58
# 1       6545       2212905.0      Maeve    Costello   36074.0  5CD9095P4M
# 2       6546             NaN        NaN         NaN   34992.0  5CD9095P0P
# 3       6547       2212767.0      Tyler     Burrell   34904.0  5CD9095P3P
# 4       6548             NaN        NaN         NaN   34894.0  5CD9095P41
# ...      ...             ...        ...         ...       ...         ...
# 5775    7352             NaN        NaN         NaN   35150.0  5CD9095LYK
# 5776    7353       2222897.0      Aaron      Malone   36775.0  5CD91717CC
# 5777    7354       2242450.0      Lucia  Diterlizzi  400243.0    P209ETGW
# 5778    7427             NaN        NaN         NaN  400701.0    P2098MYH
# 5779    7428             NaN        NaN         NaN  400653.0    P209FMTF
#
#                     MAC    Make   Part_Number Warrantyend Group Issue_Date  \
# ...

# %%
hks
# Out:
#       InternalID SerialNumber  Location  NextLocation StatusString  \
# 0          21679   2UA2200C68      A201           NaN     Disposed
# 1          21680   2UA2200C6G      A201           NaN     Disposed
# 2          21681   2UA2200C5P      A201           NaN     Disposed
# 3          21682   2UA2200C61  PALLET-A           NaN     Disposed
# 4          21683   2UA2200C5T      A201           NaN     Disposed
# ...          ...          ...       ...           ...          ...
# 19371      40947  WZP20381174      200A           NaN       Active
# 19372      40948  WZP203811KT       105           NaN       Active
# 19373      40949  WZP203811L4      105F           NaN       Active
# 19374      40950  WZP203812FC      163A           NaN       Active
# 19375      40951  WZP203811TC      129B           NaN       Active
#
#        RetiredDate InventoryNotes InventoryOther1  InventoryOther2  \
# 0              NaN            NaN             NaN              NaN
# ...
